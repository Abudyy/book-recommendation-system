# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Perform EDA (Exploratory data analysis)

# %%
#set variables books, users, ratings
#this will be used to read the data with their respective csv files
#data set is from kaggle
users = pd.read_csv('users.csv')
books = pd.read_csv('books.csv')
ratings = pd.read_csv('ratings.csv')
# Out:
# /var/folders/mh/2s4g952j6bng4lsqmld0fv0m0000gn/T/ipykernel_53807/1502575632.py:5: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   books = pd.read_csv('books.csv')

# %%
#Check the information of the datasets we are working with: this gives us an understanding of how everything is set up
#eg. entries, data types..
print(books.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271360 entries, 0 to 271359
# Data columns (total 8 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ISBN                 271360 non-null  object
#  1   Book-Title           271360 non-null  object
#  2   Book-Author          271358 non-null  object
#  3   Year-Of-Publication  271360 non-null  object
#  4   Publisher            271358 non-null  object
#  5   Image-URL-S          271360 non-null  object
#  6   Image-URL-M          271360 non-null  object
#  7   Image-URL-L          271357 non-null  object
# dtypes: object(8)
# memory usage: 16.6+ MB
# None

# %%
print(users.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 278858 entries, 0 to 278857
# Data columns (total 3 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   User-ID   278858 non-null  int64
#  1   Location  278858 non-null  object
#  2   Age       168096 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 6.4+ MB
# None

# %%
print(ratings.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1149780 entries, 0 to 1149779
# Data columns (total 3 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   User-ID      1149780 non-null  int64
#  1   ISBN         1149780 non-null  object
#  2   Book-Rating  1149780 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 26.3+ MB
# None

# %%
#use the .head() command to see the first 5 rows
#this will help us understand how the CSV file is set up
users.head()
# Out:
#    User-ID                            Location   Age
# 0        1                  nyc, new york, usa   NaN
# 1        2           stockton, california, usa  18.0
# 2        3     moscow, yukon territory, russia   NaN
# 3        4           porto, v.n.gaia, portugal  17.0
# 4        5  farnborough, hants, united kingdom   NaN

# %%
books.head()
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# ...

# %%
ratings.head()
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0
# 3   276729  052165615X            3
# 4   276729  0521795028            6

# %%
print(users.shape)
print(books.shape)
print(ratings.shape)
# Out:
# (278858, 3)
# (271360, 8)
# (1149780, 3)

# %%
#Check for any duplicated books, users, or ratings
books.duplicated().sum()

users.duplicated().sum()

ratings.duplicated().sum()
# Out:
# 0

# %%
#check for missing values or discrepencies in our data
#using .isnull() and sum them up
print("--------------------------")
users.isnull().sum()

#from the output we will see that we are missing the Age values, but our recommender system will not use this
#hence this will be fine to ignore in this particular scenario
# Out:
# --------------------------
# User-ID          0
# Location         0
# Age         110762
# dtype: int64

# %%
print("--------------------------")
books.isnull().sum()

#seems like there are a few null values, this may normally get fixed
#after some data preprocessing
# Out:
# --------------------------
# ISBN                   0
# Book-Title             0
# Book-Author            2
# Year-Of-Publication    0
# Publisher              2
# Image-URL-S            0
# Image-URL-M            0
# Image-URL-L            3
# dtype: int64

# %%
print("--------------------------")
ratings.isnull().sum()
# Out:
# --------------------------
# User-ID        0
# ISBN           0
# Book-Rating    0
# dtype: int64

# %%
#Replace the null values for the book author, publisher, and image URL-L
#Since our project does not depend on "Age" as a factor, we can simply skip those nulls

#replace the null values in our books data
books.replace(np.nan,'0',inplace = True)

#Check the null values now
books.isnull().sum()
# Out:
# ISBN                   0
# Book-Title             0
# Book-Author            0
# Year-Of-Publication    0
# Publisher              0
# Image-URL-S            0
# Image-URL-M            0
# Image-URL-L            0
# dtype: int64

# %%
#Check for the data types we are working with
books.dtypes
# Out:
# ISBN                   object
# Book-Title             object
# Book-Author            object
# Year-Of-Publication    object
# Publisher              object
# Image-URL-S            object
# Image-URL-M            object
# Image-URL-L            object
# dtype: object

# %%
users.dtypes
# Out:
# User-ID       int64
# Location     object
# Age         float64
# dtype: object

# %%
ratings.dtypes
# Out:
# User-ID         int64
# ISBN           object
# Book-Rating     int64
# dtype: object

# %%
books[books['Book-Author']=='Dale Carnegie'].head()
# Out:
#              ISBN                               Book-Title    Book-Author  \
# 1127   067142517X              HOW TO WIN FRIENDS, REVISED  Dale Carnegie
# 6090   0671723650  How To Win Friends And Influence People  Dale Carnegie
# 6091   0671733354    How to Stop Worrying and Start Living  Dale Carnegie
# 13793  3502151040                  Sorge dich nicht, lebe.  Dale Carnegie
# 33759  0671657518                       HT STOP WORRYING R  Dale Carnegie
#
#       Year-Of-Publication             Publisher  \
# 1127                 1981  Simon &amp; Schuster
# 6090                 1990                Pocket
# 6091                 1990                Pocket
# 13793                2002                Scherz
# 33759                1987                Pocket
#
#                                              Image-URL-S  \
# 1127   http://images.amazon.com/images/P/067142517X.0...
# 6090   http://images.amazon.com/images/P/0671723650.0...
# ...

# %%
books[books['Book-Author']=='Dale Carnegie']
# Out:
#               ISBN                                         Book-Title  \
# 1127    067142517X                        HOW TO WIN FRIENDS, REVISED
# 6090    0671723650            How To Win Friends And Influence People
# 6091    0671733354              How to Stop Worrying and Start Living
# 13793   3502151040                            Sorge dich nicht, lebe.
# 33759   0671657518                                 HT STOP WORRYING R
# 36799   0671616994                                 HT WIN FRIENDS   R
# 46690   0671506196                      HOW TO STOP WORRYING, REVISED
# 55357   3596506905              Der Erfolg ist in Dir. Sonderausgabe.
# 65878   067162394X              How to Stop Worrying and Start Living
# 67846   3426776723  Wie man Freunde gewinnt. Die Kunst, beliebt un...
# 69100   0671519980              The Leader In You : The Leader In You
# 92762   0671724002       The Quick and Easy Way to Effective Speaking
# ...

# %%
books[books['Year-Of-Publication']==1992].head()
# Out:
#            ISBN                                        Book-Title  \
# 56   0380715899                        A Soldier of the Great War
# 57   0553280333                                Getting Well Again
# 109  0671864769           Relics (Star Trek: The Next Generation)
# 128  0840734530  The Oneprince (The Redaemian Chronicles, Book 1)
# 135  0061099325       Coyote Waits (Joe Leaphorn/Jim Chee Novels)
#
#               Book-Author Year-Of-Publication          Publisher  \
# 56           Mark Helprin                1992         Avon Books
# 57   O. Carol Simonton Md                1992             Bantam
# 109  Michael Jan Friedman                1992          Star Trek
# 128             Bill Hand                1992  Thomas Nelson Inc
# 135        Tony Hillerman                1992        HarperTorch
#
#                                            Image-URL-S  \
# 56   http://images.amazon.com/images/P/0380715899.0...
# 57   http://images.amazon.com/images/P/0553280333.0...
# ...

# %%
import matplotlib.pyplot as plt
#create a histogram of ratings to see how the book ratings are distributed

plt.figure(figsize=(9, 7))
ratings['Book-Rating'].hist(bins=10, edgecolor='black')
plt.title('Distribution of Book Ratings')
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.grid(False)
plt.show()

# %%
import numpy as np
import seaborn as sns

# Create a sample similarity matrix for demonstration 
# finalTable = pd.pivot_table(data, index='Book-Title', columns='User-ID', values='Book-Rating').fillna(0)
# from sklearn.metrics.pairwise import cosine_similarity
# similarScores = cosine_similarity(finalTable)

plt.figure(figsize=(10, 8))
sns.heatmap(similarScores, xticklabels=False, yticklabels=False, cmap='viridis')
plt.title('Heatmap of Book Similarity Scores')
plt.xlabel('Books')
plt.ylabel('Books')
plt.show()

# %%
from sklearn.cluster import KMeans
import numpy as np

# We'll cluster based on the similarity matrix

# Number of clusters
n_clusters = 5

# Apply K-means clustering
kmeans = KMeans(n_clusters=n_clusters, random_state=0)
kmeans.fit(similarScores)

# Get cluster labels for each book
cluster_labels = kmeans.labels_

# Assign clusters to book titles
book_clusters = pd.DataFrame({'Book-Title': finalTable.index, 'Cluster': cluster_labels})

# Display books in each cluster
for cluster in range(n_clusters):
    print(f"Cluster {cluster}:")
    print(book_clusters[book_clusters['Cluster'] == cluster]['Book-Title'].tolist())
    print()
# Out:
# Cluster 0:
# ...

# %%
# Perform clustering and print results
cluster_analysis_results = book_clusters.sort_values('Cluster')
print(cluster_analysis_results)
# Out:
#                                           Book-Title  Cluster
# 146                              Devices and Desires        0
# 136                                    Dark Paradise        0
# 138                                    Dawn (Cutler)        0
# 507                                 The Color Purple        0
# 386                                  Practical Magic        0
# ..                                               ...      ...
# 599                                         The Reef        4
# 401                                          Riptide        4
# 403                                     Rising Tides        4
# 239  Heaven and Earth (Three Sisters Island Trilogy)        4
# 291    Key of Valor (Roberts, Nora. Key Trilogy, 3.)        4
#
# [706 rows x 2 columns]

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

#since our datasets are high dimensional, it will be hard to represent and visual the data as clusters
#so we can apply PCA (Principal Component Analysis) to reduce the dimensions

# Applying PCA to reduce dimensions to 2 for visualization
pca = PCA(n_components=2)
pca_result = pca.fit_transform(finalTable)

# Adding the PCA results to the dataframe
#PCA 1 and PCA 2 will capture the most variance in the data
book_clusters['PCA1'] = pca_result[:, 0]
book_clusters['PCA2'] = pca_result[:, 1]

# Plotting the clusters
plt.figure(figsize=(10, 7))
for cluster in book_clusters['Cluster'].unique():
    #loop over the unique clusters and then make a scatter plot based on the 
    #PCA1,2 criterias and if its equal to said cluster
    plt.scatter(book_clusters[book_clusters['Cluster'] == cluster]['PCA1'],
                book_clusters[book_clusters['Cluster'] == cluster]['PCA2'],
                label=f'Cluster {cluster}')
plt.title('Clustering of Books')
plt.xlabel('PCA Component 1')
plt.ylabel('PCA Component 2')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Popularity-Based Recommender System

# %%
ratings
# Out:
#          User-ID         ISBN  Book-Rating
# 0         276725   034545104X            0
# 1         276726   0155061224            5
# 2         276727   0446520802            0
# 3         276729   052165615X            3
# 4         276729   0521795028            6
# ...          ...          ...          ...
# 1149775   276704   1563526298            9
# 1149776   276706   0679447156            0
# 1149777   276709   0515107662           10
# 1149778   276721   0590442449           10
# 1149779   276723  05162443314            8
#
# [1149780 rows x 3 columns]

# %%
books
# Out:
#               ISBN                                         Book-Title  \
# 0       0195153448                                Classical Mythology
# 1       0002005018                                       Clara Callan
# 2       0060973129                               Decision in Normandy
# 3       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4       0393045218                             The Mummies of Urumchi
# ...            ...                                                ...
# 271355  0440400988                         There's a Bat in Bunk Five
# 271356  0525447644                            From One to One Hundred
# 271357  006008667X  Lily Dale : The True Story of the Town that Ta...
# 271358  0192126040                        Republic (World's Classics)
# 271359  0767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                  Book-Author Year-Of-Publication  \
# 0         Mark P. O. Morford                2002
# ...

# %%
#now let's merge both the ratings and the books together
#We do this to make it more convenient

#The number of books will naturally decrease because there are more books than ratings and only the books
#with ratings will be in the data

ratingsAndNames = ratings.merge(books,on='ISBN')

# %%
(ratingsAndNames)
# Out:
#          User-ID        ISBN  Book-Rating  \
# 0         276725  034545104X            0
# 1         276726  0155061224            5
# 2         276727  0446520802            0
# 3         276729  052165615X            3
# 4         276729  0521795028            6
# ...          ...         ...          ...
# 1031131   276704  0876044011            0
# 1031132   276704  1563526298            9
# 1031133   276706  0679447156            0
# 1031134   276709  0515107662           10
# 1031135   276721  0590442449           10
#
#                                                 Book-Title        Book-Author  \
# 0                                     Flesh Tones: A Novel         M. J. Rose
# 1                                         Rites of Passage         Judith Rae
# 2                                             The Notebook    Nicholas Sparks
# 3                                           Help!: Level 1      Philip Prowse
# ...

# %%
ratingsAndNames.groupby('Book-Title').count()
# Out:
#                                                     User-ID  ISBN  \
# Book-Title
#  A Light in the Storm: The Civil War Diary of A...        4     4
#  Always Have Popsicles                                    1     1
#  Apple Magic (The Collector's series)                     1     1
#  Ask Lily (Young Women of Faith: Lily Series, B...        1     1
#  Beyond IBM: Leadership Marketing and Finance f...        1     1
# ...                                                     ...   ...
# Ã?Â?lpiraten.                                             2     2
# Ã?Â?rger mit Produkt X. Roman.                            4     4
# Ã?Â?sterlich leben.                                       1     1
# Ã?Â?stlich der Berge.                                     3     3
# Ã?Â?thique en toc                                         2     2
#
#                                                     Book-Rating  Book-Author  \
# Book-Title
# ...

# %%
#create a data frame called numberRating and group it by the book rating count this time
#we will have to reset the indices to the default by using reset_index() function

numberRating = ratingsAndNames.groupby('Book-Title').count()['Book-Rating'].reset_index()

# %%
numberRating.rename(columns={'Book-Rating':'number_ratings'},inplace=True)

# %%
(numberRating)
# Out:
#                                                Book-Title  number_ratings
# 0        A Light in the Storm: The Civil War Diary of ...               4
# 1                                   Always Have Popsicles               1
# 2                    Apple Magic (The Collector's series)               1
# 3        Ask Lily (Young Women of Faith: Lily Series, ...               1
# 4        Beyond IBM: Leadership Marketing and Finance ...               1
# ...                                                   ...             ...
# 241066                                      Ã?Â?lpiraten.               2
# 241067                     Ã?Â?rger mit Produkt X. Roman.               4
# 241068                                Ã?Â?sterlich leben.               1
# 241069                              Ã?Â?stlich der Berge.               3
# 241070                                  Ã?Â?thique en toc               2
#
# [241071 rows x 2 columns]

# %%
#create another data frame but this time of average ratings
#we will use the mean function to find the average of the book ratings

#note: seems like panda latest version the .mean() itself wont work, hence why numeric_ ... is applied
avgRating = ratingsAndNames.groupby('Book-Title').mean(numeric_only=True)['Book-Rating'].reset_index()
avgRating.rename(columns={'Book-Rating':'avg_rating'},inplace=True)
avgRating
# Out:
#                                                Book-Title  avg_rating
# 0        A Light in the Storm: The Civil War Diary of ...    2.250000
# 1                                   Always Have Popsicles    0.000000
# 2                    Apple Magic (The Collector's series)    0.000000
# 3        Ask Lily (Young Women of Faith: Lily Series, ...    8.000000
# 4        Beyond IBM: Leadership Marketing and Finance ...    0.000000
# ...                                                   ...         ...
# 241066                                      Ã?Â?lpiraten.    0.000000
# 241067                     Ã?Â?rger mit Produkt X. Roman.    5.250000
# 241068                                Ã?Â?sterlich leben.    7.000000
# 241069                              Ã?Â?stlich der Berge.    2.666667
# 241070                                  Ã?Â?thique en toc    4.000000
#
# [241071 rows x 2 columns]

# %%
#now we will merge both the average rating and the number rating data frames.
#this is done to show both the avg rating and the # of ratings on side-by-side columns.

popularityDF = numberRating.merge(avgRating,on='Book-Title')
popularityDF
# Out:
#                                                Book-Title  number_ratings  \
# 0        A Light in the Storm: The Civil War Diary of ...               4
# 1                                   Always Have Popsicles               1
# 2                    Apple Magic (The Collector's series)               1
# 3        Ask Lily (Young Women of Faith: Lily Series, ...               1
# 4        Beyond IBM: Leadership Marketing and Finance ...               1
# ...                                                   ...             ...
# 241066                                      Ã?Â?lpiraten.               2
# 241067                     Ã?Â?rger mit Produkt X. Roman.               4
# 241068                                Ã?Â?sterlich leben.               1
# 241069                              Ã?Â?stlich der Berge.               3
# 241070                                  Ã?Â?thique en toc               2
#
#         avg_rating
# 0         2.250000
# 1         0.000000
# ...

# %%
#imp part, we need to show the books that ONLY have number of ratings greater than or equal to 250
#this will help exclude any "faulty" or random books per say. And since this is popularity based,
#it makes sense to have enough ratings

# %%
#create popularity data frame, this will only give the books with the amount when >= 250
#then sort out the columns with only the first 50 books 
popularityDF = popularityDF[popularityDF['number_ratings'] >= 250].sort_values('avg_rating',ascending=False).head(50)
popularityDF
# Out:
#                                                Book-Title  number_ratings  \
# 80434   Harry Potter and the Prisoner of Azkaban (Book 3)             428
# 80422        Harry Potter and the Goblet of Fire (Book 4)             387
# 80441      Harry Potter and the Sorcerer's Stone (Book 1)             278
# 80426   Harry Potter and the Order of the Phoenix (Boo...             347
# 80414    Harry Potter and the Chamber of Secrets (Book 2)             556
# 191612  The Hobbit : The Enchanting Prelude to The Lor...             281
# 187377  The Fellowship of the Ring (The Lord of the Ri...             368
# 80445   Harry Potter and the Sorcerer's Stone (Harry P...             575
# 211384     The Two Towers (The Lord of the Rings, Part 2)             260
# 219741                              To Kill a Mockingbird             510
# 183573                                  The Da Vinci Code             898
# 187880                 The Five People You Meet in Heaven             430
# ...

# %%
#once again merge the books to give the author name, image, and if possible, the author name
#merge will be on the Book-Title column

#we need to use the drop_duplicates function because if we merge, our columns listed will have many of the same
#books and or ratings ... etc.
popularityDF = popularityDF.merge(books,on='Book-Title').drop_duplicates('Book-Title')[['Book-Title','Book-Author','Image-URL-M','number_ratings','avg_rating']]

popularityDF
# Out:
#                                             Book-Title  \
# 0    Harry Potter and the Prisoner of Azkaban (Book 3)
# 3         Harry Potter and the Goblet of Fire (Book 4)
# 5       Harry Potter and the Sorcerer's Stone (Book 1)
# 9    Harry Potter and the Order of the Phoenix (Boo...
# 13    Harry Potter and the Chamber of Secrets (Book 2)
# 16   The Hobbit : The Enchanting Prelude to The Lor...
# 17   The Fellowship of the Ring (The Lord of the Ri...
# 26   Harry Potter and the Sorcerer's Stone (Harry P...
# 28      The Two Towers (The Lord of the Rings, Part 2)
# 39                               To Kill a Mockingbird
# 47                                   The Da Vinci Code
# 53                  The Five People You Meet in Heaven
# 55                              The Catcher in the Rye
# 62                           The Lovely Bones: A Novel
# 63                                                1984
# 72                            Prodigal Summer: A Novel
# ...

# %%
popularityDF['Image-URL-M'][0]
# Out:
# 'http://images.amazon.com/images/P/0439136350.01.MZZZZZZZ.jpg'

# %% [markdown]
# ## Collaborative Recommendation System

# %%
#group the ratings and Names merged columns by the amount of users and how many books rated, only if the amount is more
#than 200

ratingsAndNames.groupby('User-ID').count()['Book-Rating']
# Out:
# User-ID
# 2          1
# 8         17
# 9          3
# 10         1
# 12         1
#           ..
# 278846     1
# 278849     4
# 278851    23
# 278852     1
# 278854     8
# Name: Book-Rating, Length: 92106, dtype: int64

# %%
x = ratingsAndNames.groupby('User-ID').count()['Book-Rating'] > 200
#only use users that have rated more than 200 books, hence making them experienced ;)
experiencedUsers = x[x].index

# %%
x
# Out:
# User-ID
# 2         False
# 8         False
# 9         False
# 10        False
# 12        False
#           ...
# 278846    False
# 278849    False
# 278851    False
# 278852    False
# 278854    False
# Name: Book-Rating, Length: 92106, dtype: bool

# %%
#filter out the ratings only with the experienced users that we declared above, using the .isin() function
filteredRating = ratingsAndNames[ratingsAndNames['User-ID'].isin(experiencedUsers)]
filteredRating
# Out:
#          User-ID        ISBN  Book-Rating  \
# 1150      277427  002542730X           10
# 1151      277427  0026217457            0
# 1152      277427  003008685X            8
# 1153      277427  0030615321            0
# 1154      277427  0060002050            0
# ...          ...         ...          ...
# 1029357   275970  1931868123            0
# 1029358   275970  3411086211           10
# 1029359   275970  3829021860            0
# 1029360   275970  4770019572            0
# 1029361   275970  9626340762            8
#
#                                                 Book-Title  \
# 1150     Politically Correct Bedtime Stories: Modern Ta...
# 1151                    Vegetarian Times Complete Cookbook
# 1152                                              Pioneers
# 1153      Ask for May, Settle for June (A Doonesbury book)
# 1154                     On a Wicked Dawn (Cynster Novels)
# ...                                                    ...
# ...

# %%
#comment later
y = filteredRating.groupby('Book-Title').count()['Book-Rating']>=50
popularBooks = y[y].index

# %%
y
# Out:
# Book-Title
#  A Light in the Storm: The Civil War Diary of Amelia Martin, Fenwick Island, Delaware, 1861 (Dear America)    False
#  Always Have Popsicles                                                                                        False
#  Apple Magic (The Collector's series)                                                                         False
#  Beyond IBM: Leadership Marketing and Finance for the 1990s                                                   False
#  Clifford Visita El Hospital (Clifford El Gran Perro Colorado)                                                False
#                                                                                                               ...
# Ã?Â?ber das Fernsehen.                                                                                        False
# Ã?Â?ber die Pflicht zum Ungehorsam gegen den Staat.                                                           False
# ...

# %%
popularAndFilter = filteredRating = filteredRating[filteredRating['Book-Title'].isin(popularBooks)]

# %%
popularAndFilter
# Out:
#          User-ID        ISBN  Book-Rating  \
# 1150      277427  002542730X           10
# 1163      277427  0060930535            0
# 1165      277427  0060934417            0
# 1168      277427  0061009059            9
# 1174      277427  006440188X            0
# ...          ...         ...          ...
# 1029196   275970  1400031354            0
# 1029197   275970  1400031362            0
# 1029270   275970  1573229725            0
# 1029309   275970  1586210661            9
# 1029310   275970  1586212230            0
#
#                                                 Book-Title  \
# 1150     Politically Correct Bedtime Stories: Modern Ta...
# 1163                         The Poisonwood Bible: A Novel
# 1165                                    Bel Canto: A Novel
# 1168     One for the Money (Stephanie Plum Novels (Pape...
# 1174                                     The Secret Garden
# ...                                                    ...
# ...

# %%
popularAndFilter.drop_duplicates()
# Out:
#          User-ID        ISBN  Book-Rating  \
# 1150      277427  002542730X           10
# 1163      277427  0060930535            0
# 1165      277427  0060934417            0
# 1168      277427  0061009059            9
# 1174      277427  006440188X            0
# ...          ...         ...          ...
# 1029196   275970  1400031354            0
# 1029197   275970  1400031362            0
# 1029270   275970  1573229725            0
# 1029309   275970  1586210661            9
# 1029310   275970  1586212230            0
#
#                                                 Book-Title  \
# 1150     Politically Correct Bedtime Stories: Modern Ta...
# 1163                         The Poisonwood Bible: A Novel
# 1165                                    Bel Canto: A Novel
# 1168     One for the Money (Stephanie Plum Novels (Pape...
# 1174                                     The Secret Garden
# ...                                                    ...
# ...

# %%
#create a final table with the data filtered

finalTable = popularAndFilter.pivot_table(index='Book-Title',columns='User-ID',values='Book-Rating')
finalTable
# Out:
# User-ID                                             254     2276    2766    \
# Book-Title
# 1984                                                   9.0     NaN     NaN
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2nd Chance                                             NaN    10.0     NaN
# 4 Blondes                                              NaN     NaN     NaN
# A Bend in the Road                                     0.0     NaN     7.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        NaN     NaN     NaN
# You Belong To Me                                       NaN     NaN     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     NaN     NaN
# Zoya                                                   NaN     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
#
# ...

# %%
#seems like we have a shit ton of NaNs, so replace them with 0

finalTable.fillna(0,inplace=True)
finalTable
# Out:
# User-ID                                             254     2276    2766    \
# Book-Title
# 1984                                                   9.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0    10.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     7.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# ...

# %%
#import cosine similarity from sklearn library, this cosine similarity
#is crucial to help us find similar books to recommend for each particular book given
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarScores = cosine_similarity(finalTable)

similarScores.shape
#matrix similarity
# Out:
# (706, 706)

# %%
#create recommend function that takes a book name (string) as an input

#def recommend(book_name):
#    index = np.where(finalTable.index == book_name)[0][0]
#    similar_items = sorted(list(enumerate(similarScores[index])),key=lambda x:x[1],reverse=True)[1:5]
 #   
 #   for i in similar_items:
  #      print(finalTable.index[i[0]])

# %%
# Data Loading and Preprocessing (Assumed completed above this point)

def get_recommendations(book_title, n_recommendations=5):
    # Check if the book_title is in the full_books list
    if book_title in books['Book-Title'].values:
        # Check if the book_title is in the filtered_books list
        if book_title in finalTable.index:
            # Find the index of the book in the filtered books dataset for similarity calculation
            index = finalTable.index.get_loc(book_title)
            similarity_scores = list(enumerate(similarScores[index]))
            # Sort based on similarity scores
            sorted_scores = sorted(similarity_scores, key=lambda x: x[1], reverse=True)[1:5]
            # Filter recommendations from the filtered books list
            recommendations = [finalTable.index[i] for i, score in sorted_scores if finalTable.index[i] in popularAndFilter['Book-Title'].values]
            return recommendations[:n_recommendations]
        else:
            return f"'{book_title}' is not in the filtered dataset. Recommendations cannot be provided."
    else:
        return f"'{book_title}' is not found in the full dataset. Please check the title and try again."

# Example test
print(get_recommendations("1984"))
# Out:
# ['Animal Farm', "The Handmaid's Tale", 'Brave New World', 'The Vampire Lestat (Vampire Chronicles, Book II)']

# %%
#recommend("Sophies Choice")

# %%
import pickle
pickle.dump(popularityDF, open("popularity.pkl","wb"))
